# %%
pip install tiktoken
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# Collecting tiktoken
#   Downloading http://mirrors.aliyun.com/pypi/packages/5c/76/03b8286cd264f9f5550229fe21f72abc89d431a9a3c887fc365763acc5a4/tiktoken-0.3.0-cp39-cp39-macosx_10_9_x86_64.whl (735 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 735.4/735.4 kB 256.0 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests>=2.26.0 in /Users/chunhuizhang/opt/anaconda3/lib/python3.9/site-packages (from tiktoken) (2.28.1)
# Requirement already satisfied: regex>=2022.1.18 in /Users/chunhuizhang/opt/anaconda3/lib/python3.9/site-packages (from tiktoken) (2022.7.9)
# Collecting blobfile>=2
#   Downloading http://mirrors.aliyun.com/pypi/packages/c1/35/6b92aa0d86f26f0a8ab6959dd29ac4c7e96d5c1d948d4347bba12e07695a/blobfile-2.0.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 214.4 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: urllib3<3,>=1.25.3 in /Users/chunhuizhang/opt/anaconda3/lib/python3.9/site-packages (from blobfile>=2->tiktoken) (1.26.11)
# Requirement already satisfied: filelock~=3.0 in /Users/chunhuizhang/opt/anaconda3/lib/python3.9/site-packages (from blobfile>=2->tiktoken) (3.6.0)
# Collecting pycryptodomex~=3.8
#   Downloading http://mirrors.aliyun.com/pypi/packages/78/db/ec162a8fa1c7c8e03488616a01de59bb752b985f1c507ffb127b40b9d456/pycryptodomex-3.17-cp35-abi3-macosx_10_9_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 272.2 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: lxml~=4.9 in /Users/chunhuizhang/opt/anaconda3/lib/python3.9/site-packages (from blobfile>=2->tiktoken) (4.9.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chunhuizhang/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/chunhuizhang/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chunhuizhang/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (3.3)
# Installing collected packages: pycryptodomex, blobfile, tiktoken
# Successfully installed blobfile-2.0.1 pycryptodomex-3.17 tiktoken-0.3.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 认识数据集

# %%
# imports
import pandas as pd
import tiktoken
import openai
from openai.embeddings_utils import get_embedding
import numpy as np

# %%
# embedding model parameters
embedding_model = "text-embedding-ada-002"
embedding_encoding = "cl100k_base"  # this the encoding for text-embedding-ada-002
max_tokens = 8191  # the maximum for text-embedding-ada-002 is 8191

# %%
input_file = './data/fine_food_reviews_1k.csv'

# %%
df = pd.read_csv(input_file, index_col=0)
df = df[["Time", "ProductId", "UserId", "Score", "Summary", "Text"]]
df = df.sort_values('Time')
df.dropna(inplace=True)
print(df.shape)
df.drop_duplicates(subset=['Summary', 'Text'], keep='last', inplace=True)
print(df.shape)
df['Combined'] = 'Title: ' + df.Summary.str.strip() + '; Content: ' + df.Text.str.strip()
print(df.shape)
# Out:
# (1000, 6)
# (762, 6)

# %%
df.head(10)
# Out:
#            Time   ProductId          UserId  Score  \
# 0    1351123200  B003XPF9BO  A3R7JR3FMEBXQB      5
# 295  1351123200  B000LKTTTW  A14MQ40CCU8B13      5
# 292  1351123200  B002JA06Z8  A3ESIUM1JTR7KK      5
# 291  1351123200  B002HQNCBO  A1UW65ZMZ3UWD3      5
# 289  1351123200  B0048GRNZM   AXG287OY16WWL      1
# 288  1351123200  B006IMC3LS  A332LFCZ6ZPJPW      4
# 286  1351123200  B0002YGSJQ   AAUVIV5KLSC8A      5
# 284  1351123200  B005CT8R90  A19SLJ981ULZ03      5
# 283  1351123200  B0000ESTGX  A214U5SCYVJ7G4      4
# 282  1351123200  B007JT7ARQ  A17K6WB5PGT3UV      5
#
#                                                Summary  \
# 0    where does one  start...and stop... with a tre...
# 295                                   Best tomato soup
# 292        These fresh berries are truly MIRACULOUS!!!
# 291                                         Baconnaise
# 289                                               Cute
# 288                              Great Monster product
# 286                                              spicy
# 284                               Excellent but Price?
# 283                              Smooth tasting mousse
# 282             Great Shampoo, Use it all the time now
#
#                                                   Text  \
# 0    Wanted to save some to bring to my Chicago fam...
# 295  I have a hard time finding packaged food of an...
# 292  I have ordered from Ethans on three separate o...
# 291  If you are a fan of bacon you're going to like...
# 289  For some reason I thought that you got three "...
# 288  Kudos to Monster for making this coffee flavor...
# 286  It is a too spicy grocery in japan.<br /><br /...
# 284  I first heard about this on America's Test Kit...
# 283  This was very good and it was smoothe and good...
# 282  This is one of those products I would have nev...
#
#                                               Combined
# 0    Title: where does one  start...and stop... wit...
# 295  Title: Best tomato soup; Content: I have a har...
# 292  Title: These fresh berries are truly MIRACULOU...
# 291  Title: Baconnaise; Content: If you are a fan o...
# 289  Title: Cute; Content: For some reason I though...
# 288  Title: Great Monster product; Content: Kudos t...
# 286  Title: spicy; Content: It is a too spicy groce...
# 284  Title: Excellent but Price?; Content: I first ...
# 283  Title: Smooth tasting mousse; Content: This wa...
# 282  Title: Great Shampoo, Use it all the time now;...

# %%
top_n = 100
encoding = tiktoken.get_encoding(embedding_encoding)
# omit reviews that are too long to embed
df["n_tokens"] = df.Combined.apply(lambda x: len(encoding.encode(x)))
df = df[df.n_tokens <= max_tokens].tail(top_n)
df.shape
# Out:
# (100, 8)

# %%
df.head(5)
# Out:
#            Time   ProductId          UserId  Score                    Summary  \
# 650  1351209600  B0051O6P36  A1VC6419THHIET      5         Good for all cats.
# 651  1351209600  B001EO5RSQ  A33W5JAFGHYRQZ      5          Love this Cereal!
# 652  1351209600  B0045H264C  A3IYSIAKYOMKTO      5                 Wild Honey
# 679  1351209600  B000UBD88A   AWRFQYLG7LQKJ      2            Not very strong
# 654  1351209600  B001XWRMAU  A1KWVBDHBG50VZ      5  Outstanding product!.....
#
#                                                   Text  \
# 650  I just got these treats last week and they're ...
# 651  There is nothing else like this on the market....
# 652  This really is unfiltered honey made from wild...
# 679  Not as strong as the regular dark coffee.  Dis...
# 654  Great flavor.....lotsa &#34;heat&#34;....I use...
#
#                                               Combined  n_tokens
# 650  Title: Good for all cats.; Content: I just got...        81
# 651  Title: Love this Cereal!; Content: There is no...        55
# 652  Title: Wild Honey; Content: This really is unf...       107
# 679  Title: Not very strong; Content: Not as strong...        45
# 654  Title: Outstanding product!.....; Content: Gre...        43

# %%
openai.api_key = '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'
df['embedding'] = df.Combined.apply(lambda x: get_embedding(x, engine=embedding_model))

# %%
print(len(df.iloc[1]['embedding']))
print(df.iloc[1]['embedding'])
# Out:
# 1536
# [-0.012850540690124035, -0.00849321112036705, -0.005164966452866793, 0.0071384659968316555, -0.01005637925118208, 0.004018643405288458, 0.01457653846591711, -0.026352401822805405, -0.012629092670977116, -0.0014548858162015676, 0.023382384330034256, 0.009203149937093258, -0.015306017361581326, -0.03061203472316265, 0.0003667745040729642, 0.025688055902719498, 0.031002825126051903, -0.02800675481557846, 0.013560479506850243, 0.001993038924410939, -0.006281980313360691, 0.03717733919620514, -0.0031002825126051903, -0.007346888072788715, -0.004630884155631065, -0.0017895014025270939, 0.004692759830504656, -0.02218395471572876, 0.009567889384925365, 0.0030025846790522337, 0.041111309081315994, 0.014172720722854137, -0.021845268085598946, -0.0032956786453723907, -0.025531738996505737, -0.005041216034442186, -0.0029521072283387184, -0.0008605563780292869, 0.024685023352503777, -0.024190019816160202, 0.0166868157684803, 0.023069750517606735, 0.0114046111702919, 0.012427182868123055, -0.03272230923175812, -0.012264353223145008, 0.0017536787781864405, 0.009320387616753578, 0.005695792380720377, -0.006031222175806761, 0.02372106909751892, -0.00029777531744912267, -0.01798945479094982, 0.021141843870282173, -0.01148276962339878, -0.016113653779029846, 0.01865380071103573, -0.009906575083732605, 0.02639148198068142, -0.022535666823387146, 0.0032891654409468174, 0.006956096272915602, -0.019721966236829758, 0.0009256883640773594, 0.003367323661223054, -0.0006855141837149858, -0.028110966086387634, 0.003344527445733547, -0.016699841246008873, 0.000981050543487072, 0.0007351773092523217, 0.02227514050900936, -0.009287821128964424, 0.01277238316833973, 0.015735888853669167, -0.004894668702036142, -0.02417699433863163, 0.001678776927292347, 0.014107588678598404, -0.029648080468177795, 0.01873195916414261, -0.017338134348392487, -0.023577779531478882, 0.016256943345069885, 0.02563595026731491, 0.007131952792406082, 0.0010901466012001038, 0.028866495937108994, -0.01690826378762722, -0.03272230923175812, 0.03014308400452137, 0.0035041009541600943, 0.009535322897136211, 0.02342146262526512, -0.024606864899396896, 0.028866495937108994, 0.027485698461532593, 0.005002136807888746, 0.0016673789359629154, -0.012446722947061062, -0.01621786504983902, 0.015644703060388565, -0.00818709097802639, -0.017338134348392487, -0.04077262431383133, -0.0009395289234817028, 0.011267833411693573, -0.0007152306498028338, 0.02915307693183422, -0.03029940091073513, -0.0041195983067154884, -0.0024538475554436445, 0.011678165756165981, -0.0379328690469265, 0.004181473515927792, -0.001173189957626164, 0.015227858908474445, 0.0020028084982186556, -0.0010380410822108388, -0.006086584180593491, -0.007314322050660849, 0.006382934749126434, 0.02577923983335495, -0.0049891103990375996, -0.00019336058176122606, 0.02257474698126316, -0.01653049886226654, -0.007034254726022482, 0.004096801858395338, 0.0005080294795334339, 0.03449390083551407, 0.011736784130334854, 0.00799820851534605, 0.0019165087724104524, -0.013951271772384644, 0.01384706050157547, -0.030403612181544304, 0.026417534798383713, 0.006936556659638882, -0.009541836567223072, 0.013326005078852177, 0.04298711195588112, -0.004901181906461716, 0.023395409807562828, -0.014029430225491524, 0.02256171964108944, 0.006943069864064455, 0.035145219415426254, 0.007633469067513943, 0.0169864222407341, 0.005168223287910223, 0.006812805775552988, 0.030195189639925957, 0.025375422090291977, -0.007236163597553968, 0.020829210057854652, 0.006943069864064455, 0.014745881780982018, -0.003751602489501238, -0.0026427304837852716, 0.009561375714838505, -0.04538396745920181, -0.014302984811365604, -0.007346888072788715, 0.007112413179129362, 0.02540147490799427, 0.046790819615125656, -0.010414605028927326, -0.0047057862393558025, 0.015566544607281685, 0.0025645720306783915, 0.03709917888045311, -0.045253705233335495, 0.03743786737322807, -0.01857564225792885, 0.006910503841936588, -0.013299952261149883, 0.02089434117078781, -0.0390270873904228 ...

# %% [markdown]
# ## embedding

# %% [markdown]
# - dimension
# - norm

# %%
df['embed_len'] = df.embedding.apply(lambda x: len(x))
df['embed_norm'] = df.embedding.apply(lambda x: np.linalg.norm(x))

# %%
df
# Out:
#            Time   ProductId          UserId  Score  \
# 650  1351209600  B0051O6P36  A1VC6419THHIET      5
# 651  1351209600  B001EO5RSQ  A33W5JAFGHYRQZ      5
# 652  1351209600  B0045H264C  A3IYSIAKYOMKTO      5
# 679  1351209600  B000UBD88A   AWRFQYLG7LQKJ      2
# 654  1351209600  B001XWRMAU  A1KWVBDHBG50VZ      5
# ..          ...         ...             ...    ...
# 623  1351209600  B0000CFXYA  A3GS4GWPIBV0NT      1
# 624  1351209600  B0001BH5YM   A1BZ3HMAKK0NC      5
# 625  1351209600  B0009ET7TC  A2FSDQY5AI6TNX      5
# 619  1351209600  B007PA32L2  A15FF2P7RPKH6G      5
# 999  1351209600  B001EQ5GEO  A3VYU0VO6DYV6I      5
#
#                            Summary  \
# 650             Good for all cats.
# 651              Love this Cereal!
# 652                     Wild Honey
# 679                Not very strong
# 654      Outstanding product!.....
# ..                             ...
# 623  Strange inflammation response
# 624  My favorite and only  MUSTARD
# 625       My furbabies LOVE these!
# 619      got this for the daughter
# 999            I love Maui Coffee!
#
#                                                   Text  \
# 650  I just got these treats last week and they're ...
# 651  There is nothing else like this on the market....
# 652  This really is unfiltered honey made from wild...
# 679  Not as strong as the regular dark coffee.  Dis...
# 654  Great flavor.....lotsa &#34;heat&#34;....I use...
# ..                                                 ...
# 623  Truthfully wasn't crazy about the taste of the...
# 624  You've just got to experience this mustard... ...
# 625  Shake the container and they come running. Eve...
# 619  all i have heard since she got a kuerig is why...
# 999  My first experience with Maui Coffee was bring...
#
#                                               Combined  n_tokens  \
# 650  Title: Good for all cats.; Content: I just got...        81
# 651  Title: Love this Cereal!; Content: There is no...        55
# 652  Title: Wild Honey; Content: This really is unf...       107
# 679  Title: Not very strong; Content: Not as strong...        45
# 654  Title: Outstanding product!.....; Content: Gre...        43
# ..                                                 ...       ...
# 623  Title: Strange inflammation response; Content:...       110
# 624  Title: My favorite and only  MUSTARD; Content:...        80
# 625  Title: My furbabies LOVE these!; Content: Shak...        47
# 619  Title: got this for the daughter; Content: all...        50
# 999  Title: I love Maui Coffee!; Content: My first ...       118
#
#                                              embedding  embed_len  embed_norm
# 650  [-0.020426278933882713, -0.022335030138492584,...       1536         1.0
# 651  [-0.012850540690124035, -0.00849321112036705, ...       1536         1.0
# 652  [0.0019596752244979143, -0.010193675756454468,...       1536         1.0
# 679  [-0.0016112793236970901, -0.026598896831274033...       1536         1.0
# 654  [-0.00573874544352293, 0.007031316868960857, 0...       1536         1.0
# ..                                                 ...        ...         ...
# 623  [0.00011091353371739388, -0.00466986745595932,...       1536         1.0
# 624  [-0.020842211320996284, -0.013073143549263477,...       1536         1.0
# 625  [-0.009749102406203747, -0.0068712360225617886...       1536         1.0
# 619  [-0.00521062919870019, 0.0009606690146028996, ...       1536         1.0
# 999  [-0.006080752704292536, -0.015055240131914616,...       1536         1.0
#
# [100 rows x 11 columns]

# %% [markdown]
# ## semantic search base text embedding

# %%
from openai.embeddings_utils import get_embedding, cosine_similarity

# search through the reviews for a specific product
def search_reviews(df, query, n=3, pprint=True):
    query_embed = get_embedding(
        query,
        engine=embedding_model
    )
    df["similarity"] = df.embedding.apply(lambda x: cosine_similarity(x, query_embed))

    results = (
        df.sort_values("similarity", ascending=False)
        .head(n)
        .Combined.str.replace("Title: ", "")
        .str.replace("; Content:", ": ")
    )
    if pprint:
        n = 1
        for r in results:
            print('top{}:'.format(n))
            n += 1
            # print(r[:200])
            print(r[:])
            print('==================================')
    return results


results = search_reviews(df, "good coffee", n=3)
# Out:
# top1:
# super coffee:  Great coffee and so easy to brew.  This coffee has great aroma and is good to the last drop.  I actually like all the brands.  This is the way coffee should taste!!
# ==================================
# top2:
# Delicious!!!!:  A coffee treat. Now that my husband and I drink this coffee, there is no going back to the plain stuff ;).
# ==================================
# top3:
# Full- bodied without a bitter after-taste:  This is my everyday coffee choice...a good all around crowd pleaser.  Green mountain Sumatra would be my back-up-for-a-change-of-pace second choice...nice to have both on hand!
# ==================================

# %%
results = search_reviews(df, "bad rice", n=3)
# Out:
# top1:
# Unbelievable! the best rice I have ever had.:  I hardly ever write reviews, this rice is so good that I have to write about it.<br /><br />I live in Hawaii and have never seen this Caribbean rice mix for sale in any store. I came across this while searching Amazon, so glad I gave it a try!.. "try it" I do not think you'll be disappointed.<br /><br />I have added the chopped up chicken as suggested but i also added small chopped onion, it is unbelievable! Another great way to make it even better is try adding fresh Mango while it is simmering or if you cant find it fresh, use canned mango nectar, substitute 1/4 cup of the water for the mango juice. Super Good!. Also instead of 2 1/2 cups water as suggested  use only 2 1/4 cups water, brings out the flavor a little bit more I think (2 cups water / 1/4 cup mango nectar).
# ==================================
# top2:
# I love this stuff:  Hard to find in the grocery. I buy it by the case online. One box makes four lunches with some blackened chicken for protein. There is something about the sweet pineapple and curry that makes this rice mix delicious.
# ==================================
# top3:
# Good quality, great to cook with:  We have enjoyed using this product.  I like it specially for cooking lightly breaded fish or vegetables.  It gives a faint pleasant taste of coconut.  I can hardly wait to do some tropical dishes.
# ==================================

# %%
results = search_reviews(df, "hamburger", n=3)
# Out:
# top1:
# Great for HS lunch:  Great for HS lunch, kid enjoy as a snack also, will buy again. Salted chips are good too, tried them too.
# ==================================
# top2:
# I love this stuff:  Hard to find in the grocery. I buy it by the case online. One box makes four lunches with some blackened chicken for protein. There is something about the sweet pineapple and curry that makes this rice mix delicious.
# ==================================
# top3:
# Dogs love it.:  This is the "all gone" treat after dinner.  It's the only treat that the dogs work for; and I did run the chance of losing a hand.  They know a new command now:  "be gentle" when taking liver treats.
# ==================================
